# %%
import glassdoor_scraper as gs
import pandas as pd
path= "C:/Users/Raghav/Documents/salary_proj/chromedriver"
df=gs.get_jobs('data scientist',12,False,path,13)
# Out:
# x out worked
# Progress: 0/12
# Progress: 1/12
# Progress: 2/12
# Progress: 3/12
# Progress: 4/12
# Progress: 5/12
# Progress: 6/12
# Progress: 7/12
# Progress: 8/12
# Progress: 9/12
# Progress: 10/12
# Progress: 11/12
# Progress: 12/12

# %%
df
# Out:
#                                  Job Title              Salary Estimate  \
# 0        Data Scientist - Machine Learning  $98K-$156K (Glassdoor Est.)
# 1          Data Scientist/Machine Learning  $98K-$156K (Glassdoor Est.)
# 2                      Risk Data Scientist  $98K-$156K (Glassdoor Est.)
# 3                           Data Scientist  $98K-$156K (Glassdoor Est.)
# 4   Data Scientist / Applied Mathematician  $98K-$156K (Glassdoor Est.)
# 5        Data Scientist, Product Analytics  $98K-$156K (Glassdoor Est.)
# 6                           Data Scientist  $98K-$156K (Glassdoor Est.)
# 7                           Data Scientist  $98K-$156K (Glassdoor Est.)
# 8   Data Scientist, Transaction Monitoring  $98K-$156K (Glassdoor Est.)
# 9                 Marketing Data Scientist  $98K-$156K (Glassdoor Est.)
# 10                          Data Scientist  $98K-$156K (Glassdoor Est.)
# 11                   Senior Data Scientist  $98K-$156K (Glassdoor Est.)
#
# ...
